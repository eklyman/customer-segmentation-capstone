# %%
import io
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import boto3
import sagemaker
from sagemaker import get_execution_role, PCA

# %%
session = sagemaker.Session()
print(session)

role = get_execution_role()
print(role)

bucket = session.default_bucket()
# Out:
# <sagemaker.session.Session object at 0x7fa2616a88d0>
# arn:aws:iam::240038582877:role/service-role/AmazonSageMaker-ExecutionRole-20191028T202433

# %%
# load data
prefix = 'segmentation'

data_key= prefix + '/azdias_scaled.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)

# %%
tmp_list = []

for chunk in pd.read_csv(data_location, chunksize=100000):
    tmp_list.append(chunk)
    
df = pd.concat(tmp_list, axis=0).drop(['Unnamed: 0'], axis=1)
print(df.shape)
del tmp_list
# Out:
# (891221, 93)

# %%
df.head()
# Out:
#         LNR  AGER_TYP  D19_BANKEN_ANZ_12  D19_BANKEN_ANZ_24  D19_BANKEN_DATUM  \
# 0  0.806268      0.00                0.0           0.000000          1.000000
# 1  0.806273      0.00                0.0           0.000000          1.000000
# 2  0.806279      0.00                0.0           0.000000          1.000000
# 3  0.806280      0.75                0.0           0.000000          1.000000
# 4  0.806297      0.00                0.5           0.833333          0.444444
#
#    D19_BANKEN_DIREKT  D19_BANKEN_GROSS  D19_BANKEN_LOKAL  \
# 0           0.000000          0.000000               0.0
# 1           0.000000          0.000000               0.0
# 2           0.000000          0.000000               0.0
# 3           0.000000          0.000000               0.0
# 4           0.142857          0.333333               0.0
#
#    D19_BANKEN_OFFLINE_DATUM  D19_BANKEN_ONLINE_DATUM  ...  SEMIO_RAT  \
# 0                       1.0                 1.000000  ...   0.500000
# 1                       1.0                 1.000000  ...   0.833333
# 2                       1.0                 1.000000  ...   0.500000
# 3                       1.0                 1.000000  ...   0.333333
# 4                       1.0                 0.444444  ...   0.166667
#
#    SEMIO_REL  SEMIO_SOZ  SEMIO_TRADV  SEMIO_VERT  SHOPPER_TYP  VERS_TYP  \
# 0   1.000000   0.166667     0.333333         0.0         0.00  0.000000
# 1   0.500000   0.666667     0.833333         0.0         1.00  1.000000
# 2   0.333333   0.500000     0.333333         0.5         0.75  0.666667
# 3   0.166667   0.666667     0.500000         0.5         0.50  0.666667
# 4   0.500000   0.833333     0.166667         1.0         0.75  1.000000
#
#    ZABEOTYP  ANREDE_KZ  ALTERSKATEGORIE_GROB
# 0       0.4        0.0                 0.125
# 1       0.8        1.0                 0.000
# 2       0.8        1.0                 0.250
# 3       0.4        1.0                 0.375
# 4       0.6        0.0                 0.250
#
# [5 rows x 93 columns]

# %%
# prepare space to store model artifacts
prefix = 'pca'
output_path = 's3://{}/{}/'.format(bucket, prefix)
output_path
# Out:
# 's3://sagemaker-us-east-2-240038582877/pca/'

# %%
N_COMPONENTS = 10
pca = PCA(role=role,
          train_instance_count=1,
          train_instance_type='ml.c4.xlarge',
          output_path=output_path,
          num_components=N_COMPONENTS,
          sagemaker_session=session)

# %%
#must convert to RecordSet for built in sagemaker models

#convert df to np array (pass this to the deployed PCA model later)
train_data_np = df.values.astype('float32')

#convert to RecordSet format
formatted_train_data = pca.record_set(train_data_np)

# %%
pca.fit(formatted_train_data)
# Out:
# 2020-04-21 00:22:58 Starting - Starting the training job...
# 2020-04-21 00:23:00 Starting - Launching requested ML instances...
# 2020-04-21 00:23:58 Starting - Preparing the instances for training......
# 2020-04-21 00:24:37 Downloading - Downloading input data...
# 2020-04-21 00:25:19 Training - Downloading the training image.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/21/2020 00:25:35 INFO 140067980412736] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'_num_gpus': u'auto', u'_log_level': u'info', u'subtract_mean': u'true', u'force_dense': u'true', u'epochs': 1, u'algorithm_mode': u'regular', u'extra_components': u'-1', u'_kvstore': u'dist_sync', u'_num_kv_servers': u'auto'}
# [04/21/2020 00:25:35 INFO 140067980412736] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'93', u'mini_batch_size': u'500', u'num_components': u'10'}
# [04/21/2020 00:25:35 INFO 140067980412736] Final configuration: {u'num_components': u'10', u'_num_gpus': u'auto', u'_log_level': u'info', u'subtract_mean': u'true', u'force_dense': u'true', u'epochs': 1, u'algorithm_mode': u'regular', u'feature_dim': u'93', u'extra_components': u'-1', u'_kvstore': u'dist_sync', u'_num_kv_servers': u'auto', u'mini_batch_size': u'500'}
# [04/21/2020 00:25:35 WARNING 140067980412736] Loggers have already been setup.
# [04/21/2020 00:25:37 INFO 140067980412736] Launching parameter server for role scheduler
# [04/21/2020 00:25:37 INFO 140067980412736] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/1abe37bd-fa5b-47eb-9af8-7c0613efaf3f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-04-21-00-22-58-796', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-104-7.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/257631e3-1a65-4c2f-95bf-e15b3845f559', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:240038582877:training-job/pca-2020-04-21-00-22-58-796', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/21/2020 00:25:37 INFO 140067980412736] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/1abe37bd-fa5b-47eb-9af8-7c0613efaf3f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.104.7', 'AWS_REGION': 'us-east-2', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-04-21-00-22-58-796', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-104-7.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/257631e3-1a65-4c2f-95bf-e15b3845f559', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:240038582877:training-job/pca-2020-04-21-00-22-58-796', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/21/2020 00:25:37 INFO 140067980412736] Launching parameter server for role server
# [04/21/2020 00:25:37 INFO 140067980412736] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/1abe37bd-fa5b-47eb-9af8-7c0613efaf3f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-04-21-00-22-58-796', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-104-7.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/257631e3-1a65-4c2f-95bf-e15b3845f559', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:240038582877:training-job/pca-2020-04-21-00-22-58-796', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/21/2020 00:25:37 INFO 140067980412736] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/1abe37bd-fa5b-47eb-9af8-7c0613efaf3f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.104.7', 'AWS_REGION': 'us-east-2', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-04-21-00-22-58-796', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-104-7.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/257631e3-1a65-4c2f-95bf-e15b3845f559', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:240038582877:training-job/pca-2020-04-21-00-22-58-796', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/21/2020 00:25:37 INFO 140067980412736] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/1abe37bd-fa5b-47eb-9af8-7c0613efaf3f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '1', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.104.7', 'AWS_REGION': 'us-east-2', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-04-21-00-22-58-796', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-104-7.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/257631e3-1a65-4c2f-95bf-e15b3845f559', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:240038582877:training-job/pca-2020-04-21-00-22-58-796', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 61 is a shell:scheduler.
# Process 70 is a shell:server.
# Process 1 is a worker.
# [04/21/2020 00:25:37 INFO 140067980412736] Using default worker.
# [04/21/2020 00:25:37 INFO 140067980412736] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [04/21/2020 00:25:37 INFO 140067980412736] Loaded iterator creator application/x-labeled-vector-protobuf for content type ('application/x-labeled-vector-protobuf', '1.0')
# [04/21/2020 00:25:37 INFO 140067980412736] Loaded iterator creator protobuf for content type ('protobuf', '1.0')
# [04/21/2020 00:25:37 INFO 140067980412736] Create Store: dist_sync
# [04/21/2020 00:25:37 INFO 140067980412736] nvidia-smi took: 0.0252599716187 secs to identify 0 gpus
# [04/21/2020 00:25:37 INFO 140067980412736] Number of GPUs being used: 0
# [04/21/2020 00:25:37 INFO 140067980412736] The default executor is <PCAExecutor on cpu(0)>.
# [04/21/2020 00:25:37 INFO 140067980412736] 93 feature(s) found in 'data'.
# [04/21/2020 00:25:37 INFO 140067980412736] <PCAExecutor on cpu(0)> is assigned to batch slice from 0 to 499.
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 771.7719078063965, "sum": 771.7719078063965, "min": 771.7719078063965}}, "EndTime": 1587428737.994981, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1587428737.195105}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1587428737.99519, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1587428737.995155}
#
# [2020-04-21 00:25:37.999] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 803, "num_examples": 1, "num_bytes": 200000}
# [2020-04-21 00:25:39.765] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 1757, "num_examples": 1783, "num_bytes": 356488400}
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "update.time": {"count": 1, "max": 1765.542984008789, "sum": 1765.542984008789, "min": 1765.542984008789}}, "EndTime": 1587428739.765536, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1587428737.995082}
#
# [04/21/2020 00:25:39 INFO 140067980412736] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1783, "sum": 1783.0, "min": 1783}, "Number of Batches Since Last Reset": {"count": 1, "max": 1783, "sum": 1783.0, "min": 1783}, "Number of Records Since Last Reset": {"count": 1, "max": 891221, "sum": 891221.0, "min": 891221}, "Total Batches Seen": {"count": 1, "max": 1783, "sum": 1783.0, "min": 1783}, "Total Records Seen": {"count": 1, "max": 891221, "sum": 891221.0, "min": 891221}, "Max Records Seen Between Resets": {"count": 1, "max": 891221, "sum": 891221.0, "min": 891221}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1587428739.766008, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "PCA", "epoch": 0}, "StartTime": 1587428737.999954}
#
# [04/21/2020 00:25:39 INFO 140067980412736] #throughput_metric: host=algo-1, train throughput=504606.843441 records/second
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 21.744966506958008, "sum": 21.744966506958008, "min": 21.744966506958008}}, "EndTime": 1587428739.788053, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1587428739.765725}
#
# [04/21/2020 00:25:39 INFO 140067980412736] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 4274.303913116455, "sum": 4274.303913116455, "min": 4274.303913116455}, "setuptime": {"count": 1, "max": 1558.8409900665283, "sum": 1558.8409900665283, "min": 1558.8409900665283}}, "EndTime": 1587428739.823643, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1587428739.788105}
# 2020-04-21 00:25:49 Uploading - Uploading generated training model
# 2020-04-21 00:25:49 Completed - Training job completed
# Training seconds: 72
# Billable seconds: 72

# %%
#get from AWS console
training_job_name = 'pca-2020-04-21-00-22-58-796'
model_key = os.path.join(prefix, training_job_name, 'output/model.tar.gz')
print(model_key)

boto3.resource('s3').Bucket(bucket).download_file(model_key, 'model.tar.gz')

os.system('tar -zxvf model.tar.gz')
os.system('unzip model_algo-1')
# Out:
# pca/pca-2020-04-21-00-22-58-796/output/model.tar.gz
# 2304

# %%
import mxnet as mx

pca_model_params = mx.ndarray.load('model_algo-1')
# kmeans_numpy = pca_model_params[0].asnumpy()
# distortions = sum(np.min(cdist(formatted_train_data, kmeans_numpy, 'euclidian')))
# print(distortions)

# %%
#mean - mean subtracted from a component in order to center it
#v - makeup of the principal component (same as components_)
#s - singular values of the components for the PCA transformation, % of variance from the projected future space

#explained-variance-ratio ~= square(s) / sum(square(s))

s=pd.DataFrame(pca_model_params['s'].asnumpy())
v=pd.DataFrame(pca_model_params['v'].asnumpy())

n_principal_components = 5

start_idx = N_COMPONENTS - n_principal_components

print(s.iloc[start_idx:])
# Out:
#              0
# 5   461.793243
# 6   587.926880
# 7   808.306152
# 8   878.501404
# 9  1095.519653

# %%
#what is the smallest number or principal comonents that captures at least 80% of the
#total variance in the dataset?

def explained_variance(s, n_top_components):
    exp_variance = np.square(s.iloc[start_idx:]).sum() / np.square(s).sum()
    return exp_variance

# %%
n_top_components = 10
exp_variance = explained_variance(s, n_top_components)
print(exp_variance)
# Out:
# 0    0.817895
# dtype: float32

# %%
import seaborn as sns

def display_component(v, features_list, component_num, n_weights=10):
        row_idx = N_COMPONENTS-component_num
        v_l_row = v.iloc[:, row_idx]
        v_1 = np.squeeze(v_l_row.values)
        
        compos = pd.DataFrame(list(zip(v_1, features_list)), columns=['weights', 'features'])
        
        # get absolute value
        #weights can be neg/pos and we'll sort by magnitude
        
        compos['abs_weights'] = compos['weights'].apply(lambda x: abs(x))
        sorted_compos = compos.sort_values('abs_weights', ascending=False).head(n_weights)
        print(sorted_compos)
        
        ax=plt.subplots(figsize=(10,6))
        ax=sns.barplot(data=sorted_compos, x="weights", y="features", palette="Blues_d")
        ax.set_title("PCA Component Makeup Component #{}".format(component_num))
        plt.show()

# %%
display_component(v, df.columns.values, component_num=5, n_weights=25)
# Out:
#      weights                  features  abs_weights
# 37  0.354022              D19_SONSTIGE     0.354022
# 38  0.294650               D19_TECHNIK     0.294650
# 34  0.285852                D19_REISEN     0.285852
# 15  0.264812               D19_BUCH_CD     0.264812
# 69  0.246079          GREEN_AVANTGARDE     0.246079
# 30  0.219161              D19_KOSMETIK     0.219161
# 25  0.216859   D19_GESAMT_ONLINE_DATUM     0.216859
# 23  0.204459          D19_GESAMT_DATUM     0.204459
# 51  0.201541  D19_VERSAND_ONLINE_DATUM     0.201541
# 26  0.187582              D19_HANDWERK     0.187582
# 49  0.185057         D19_VERSAND_DATUM     0.185057
# 22 -0.167395         D19_GESAMT_ANZ_24     0.167395
# 59  0.163235         D19_VOLLSORTIMENT     0.163235
# 35  0.149535         D19_SAMMELARTIKEL     0.149535
# 29  0.145515         D19_KONSUMTYP_MAX     0.145515
# 21 -0.142331         D19_GESAMT_ANZ_12     0.142331
# 48 -0.136202        D19_VERSAND_ANZ_24     0.136202
# 47 -0.114798        D19_VERSAND_ANZ_12     0.114798
# 67 -0.112373                 FINANZTYP     0.112373
# 27  0.109618             D19_HAUS_DEKO     0.109618
# 13  0.109589               D19_BILDUNG     0.109589
# 12  0.103715       D19_BEKLEIDUNG_REST     0.103715
# 28  0.099940         D19_KINDERARTIKEL     0.099940
# 65  0.097620     FINANZ_UNAUFFAELLIGER     0.097620
# 60  0.089875         D19_WEIN_FEINKOST     0.089875

# %%
training_job_name = pca.latest_training_job.name
training_job_name

# %%
attached_estimator = pca.attach(training_job_name)

# %%
# %%time

# pca_predictor = pca.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
pca_predictor = attached_estimator.deploy(initial_instance_count=1, instance_type='ml.t2.medium')

# %%
# %%time

#try chunking data to PCA endpoint
train_pca = []

for chunk in np.array_split(train_data_np, 5000):
    train_pca.append(pca_predictor.predict(chunk))

# %%
flattened_train_pca = [list for sublist in train_pca for list in sublist]
del train_pca

# %%
def create_transformed_df(flattened_train_pca, scaled_df, n_top_components):
    start_idx = N_COMPONENTS - n_top_components
    new_values = [x.label['projection'].float32_tensor.values for x in flattened_train_pca]
    df = pd.DataFrame(index=scaled_df.index.values, data=new_values)
    
    top_components = df.iloc[:,start_idx:]
    return top_components.iloc[:,::-1]

# %%
flattened_train_pca = flattened_train_pca[:-1]
len(flattened_train_pca)

# %%
df = df[:-1]
df.shape[0]

# %%
len(flattened_train_pca) == df.shape[0]

# %%
import numpy as np
set1, set2, set3, set4 = np.array_split(flattened_train_pca, 4)

# %%
print(len(set1))
print(len(set2))
print(len(set3))
print(len(set4))

# %%
# %%time

import math
start_idx = 668415
end_idx = 891220
chunk_num = 4

top_n=5
cols = ['c1', 'c2', 'c3', 'c4', 'c5']


print('beginning', start_idx, end_idx)
print('scaled df index values: %.2d and x shape %.2d' % (df.iloc[start_idx:end_idx].shape[0], set1.shape[0]))
print()
df_transformed = create_transformed_df(set1, df.iloc[start_idx:end_idx], n_top_components=top_n)
df_transformed.columns = cols

file_name = '{}_transformed.csv'.format(chunk_num)
print(file_name)
df_transformed.to_csv(file_name)

# %%
print(df.iloc[0:222805].shape[0])
print(df.iloc[222805:445610].shape[0])
print(df.iloc[445610:668415].shape[0])
print(df.iloc[668415:891220].shape[0])
print(df.shape[0])

# %%
len(flattened_train_pca)

# %%
session.delete_endpoint(pca_predictor.endpoint)

# %% [markdown]
# ### KMeans Training

# %%
df1_transformed = pd.read_csv('1_transformed.csv')

# %%
df2_transformed = pd.read_csv('2_transformed.csv')

# %%
df3_transformed = pd.read_csv('3_transformed.csv')

# %%
df4_transformed = pd.read_csv('4_transformed.csv')

# %%
df1_transformed = df1_transformed.append(df4_transformed)
print(df1_transformed.shape[0])

del df4_transformed
# Out:
# 891220

# %%
df1_transformed = df1_transformed.drop('Unnamed: 0', axis=1)
df1_transformed.head()
# Out:
#          c1        c2        c3        c4        c5
# 0 -1.721670  0.423881  0.200654 -1.470560 -0.037066
# 1 -1.050703  0.961696  0.697668  1.330895  0.107373
# 2 -0.168961 -0.205433  0.822409  1.033169  1.122331
# 3  0.038208 -1.279235 -0.058969  0.382375  0.860651
# 4  2.664234  0.447640 -0.592593 -0.372019 -1.152814

# %%
# KMeans

from sagemaker import KMeans

prefix = 'segmentation'
output_path = 's3://{}/{}/'.format(bucket, prefix)
print(output_path)
# Out:
# s3://sagemaker-us-east-2-240038582877/segmentation/

# %%
kmeans = KMeans(
    role=role,
    train_instance_count=1,
    train_instance_type='ml.c4.xlarge',
    output_path=output_path,
    sagemaker_session=session,
    k=8
)

# %%
# %%time
train_data_np = df1_transformed.values.astype('float32')
formatted_train_data = kmeans.record_set(train_data_np)
# Out:
# CPU times: user 18.8 s, sys: 126 ms, total: 18.9 s
# Wall time: 19.5 s

# %%
# %%time
kmeans.fit(formatted_train_data, logs=True)
# Out:
# 2020-04-24 03:35:59 Starting - Starting the training job...
# 2020-04-24 03:36:01 Starting - Launching requested ML instances...
# 2020-04-24 03:36:56 Starting - Preparing the instances for training......
# 2020-04-24 03:37:54 Downloading - Downloading input data......
# 2020-04-24 03:38:58 Training - Training image download completed. Training in progress.
# 2020-04-24 03:38:58 Uploading - Uploading generated training model
# 2020-04-24 03:38:58 Completed - Training job completed
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/24/2020 03:38:48 INFO 139721160144704] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'_enable_profiler': u'false', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [04/24/2020 03:38:48 INFO 139721160144704] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'5', u'k': u'8', u'force_dense': u'True'}
# [04/24/2020 03:38:48 INFO 139721160144704] Final configuration: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'feature_dim': u'5', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'8', u'_num_slices': u'1'}
# [04/24/2020 03:38:48 WARNING 139721160144704] Loggers have already been setup.
# Process 1 is a worker.
# [04/24/2020 03:38:48 INFO 139721160144704] Using default worker.
# [04/24/2020 03:38:48 INFO 139721160144704] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [04/24/2020 03:38:48 INFO 139721160144704] Create Store: local
# [04/24/2020 03:38:48 INFO 139721160144704] nvidia-smi took: 0.0251681804657 secs to identify 0 gpus
# [04/24/2020 03:38:48 INFO 139721160144704] Number of GPUs being used: 0
# [04/24/2020 03:38:48 INFO 139721160144704] Setting up with params: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'feature_dim': u'5', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'8', u'_num_slices': u'1'}
#progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 179, "sum": 179.0, "min": 179}, "Number of Batches Since Last Reset": {"count": 1, "max": 179, "sum": 179.0, "min": 179}, "Number of Records Since Last Reset": {"count": 1, "max": 891220, "sum": 891220.0, "min": 891220}, "Total Batches Seen": {"count": 1, "max": 180, "sum": 180.0, "min": 180}, "Total Records Seen": {"count": 1, "max": 896220, "sum": 896220.0, "min": 896220}, "Max Records Seen Between Resets": {"count": 1, "max": 891220, "sum": 891220.0, "min": 891220}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1587699530.703926, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1587699528.587481}
#
# [04/24/2020 03:38:50 INFO 139721160144704] #throughput_metric: host=algo-1, train throughput=421064.492322 records/second
# [04/24/2020 03:38:50 WARNING 139721160144704] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/24/2020 03:38:50 INFO 139721160144704] shrinking 80 centers into 8
# [04/24/2020 03:38:50 INFO 139721160144704] local kmeans attempt #0. Current mean square distance 0.689284
# [04/24/2020 03:38:50 INFO 139721160144704] local kmeans attempt #1. Current mean square distance 0.685743
# [04/24/2020 03:38:50 INFO 139721160144704] local kmeans attempt #2. Current mean square distance 0.688152
# [04/24/2020 03:38:50 INFO 139721160144704] local kmeans attempt #3. Current mean square distance 0.863525
# [04/24/2020 03:38:50 INFO 139721160144704] local kmeans attempt #4. Current mean square distance 0.760446
# [04/24/2020 03:38:50 INFO 139721160144704] local kmeans attempt #5. Current mean square distance 0.727578
# [04/24/2020 03:38:50 INFO 139721160144704] local kmeans attempt #6. Current mean square distance 0.686416
# [04/24/2020 03:38:50 INFO 139721160144704] local kmeans attempt #7. Current mean square distance 0.691866
# [04/24/2020 03:38:50 INFO 139721160144704] local kmeans attempt #8. Current mean square distance 0.705042
# [04/24/2020 03:38:50 INFO 139721160144704] local kmeans attempt #9. Current mean square distance 0.731265
# [04/24/2020 03:38:50 INFO 139721160144704] finished shrinking process. Mean Square Distance = 1
# [04/24/2020 03:38:50 INFO 139721160144704] #quality_metric: host=algo-1, train msd <loss>=0.685743391514
# [04/24/2020 03:38:50 INFO 139721160144704] predict compute msd took: 37.8376%, (0.793191 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] gradient: cluster size  took: 23.8687%, (0.500362 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] compute all data-center distances: inner product took: 14.9344%, (0.313071 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] gradient: cluster center took: 6.5105%, (0.136480 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] update state and report convergance took: 3.5646%, (0.074725 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] compute all data-center distances: point norm took: 3.3433%, (0.070087 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] batch data loading with context took: 3.0351%, (0.063625 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] collect from kv store took: 2.1271%, (0.044590 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] gradient: one_hot took: 2.1065%, (0.044159 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] compute all data-center distances: center norm took: 1.2526%, (0.026258 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] splitting centers key-value pair took: 1.2442%, (0.026083 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] predict minus dist took: 0.1661%, (0.003481 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] update set-up time took: 0.0093%, (0.000195 secs)
# [04/24/2020 03:38:50 INFO 139721160144704] TOTAL took: 2.09630680084
# [04/24/2020 03:38:50 INFO 139721160144704] Number of GPUs being used: 0
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 293.8230037689209, "sum": 293.8230037689209, "min": 293.8230037689209}, "initialize.time": {"count": 1, "max": 43.260812759399414, "sum": 43.260812759399414, "min": 43.260812759399414}, "model.serialize.time": {"count": 1, "max": 0.14710426330566406, "sum": 0.14710426330566406, "min": 0.14710426330566406}, "update.time": {"count": 1, "max": 2116.2350177764893, "sum": 2116.2350177764893, "min": 2116.2350177764893}, "epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "state.serialize.time": {"count": 1, "max": 1.667022705078125, "sum": 1.667022705078125, "min": 1.667022705078125}, "_shrink.time": {"count": 1, "max": 292.0091152191162, "sum": 292.0091152191162, "min": 292.0091152191162}}, "EndTime": 1587699531.000028, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1587699528.528165}
#
# [04/24/2020 03:38:51 INFO 139721160144704] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2536.445140838623, "sum": 2536.445140838623, "min": 2536.445140838623}, "setuptime": {"count": 1, "max": 13.61393928527832, "sum": 13.61393928527832, "min": 13.61393928527832}}, "EndTime": 1587699531.001683, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1587699531.000136}
# Training seconds: 64
# Billable seconds: 64
# CPU times: user 510 ms, sys: 12.9 ms, total: 523 ms
# Wall time: 3min 11s

# %%
print(kmeans)
# Out:
# <sagemaker.amazon.kmeans.KMeans object at 0x7fa260104a58>

# %%
# %%time
kmeans_predictor = kmeans.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# -----------------!CPU times: user 314 ms, sys: 17.5 ms, total: 331 ms
# Wall time: 8min 32s

# %%
# %%time

#try chunking data to PCA endpoint
cluster_info = []

chunk_num = 0

#is this appending as expected?

for chunk in np.array_split(train_data_np, 2000):
    cluster_info.append(kmeans_predictor.predict(chunk))
    print('Chunk num: {}'.format(chunk_num+=1))
# Out:
# CPU times: user 1min 2s, sys: 1.28 s, total: 1min 4s
# Wall time: 2min 42s

# %%
len(cluster_info)
# Out:
# 2000

# %%
#explore clusters
data_idx = 1

print(df1_transformed.index[data_idx])
cluster_info[data_idx]
# Out:
# 1
# [label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.601616382598877
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 7.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.2704105377197266
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.6230112910270691
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.1128853559494019
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.5193835496902466
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.712523341178894
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 0.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.8316196799278259
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.9701133370399475
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 0.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.1668769121170044
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.5559883713722229
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.925944983959198
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 7.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.4047943353652954
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.2852839231491089
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.4929152727127075
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.1529784202575684
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 7.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.3480560779571533
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.6192538142204285
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.164768934249878
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.0349959135055542
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 0.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.5657079219818115
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.37980496883392334
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 0.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.99747234582901
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.882601022720337
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.8489782810211182
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1