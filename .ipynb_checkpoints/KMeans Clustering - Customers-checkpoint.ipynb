# %%
import io
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import boto3
import sagemaker
from sagemaker import get_execution_role, PCA

# %%
session = sagemaker.Session()
print(session)

role = get_execution_role()
print(role)

bucket = session.default_bucket()
# Out:
# <sagemaker.session.Session object at 0x7efc7cb15b00>
# arn:aws:iam::240038582877:role/service-role/AmazonSageMaker-ExecutionRole-20191028T202433

# %% [markdown]
# ### Customers

# %%
d# load data
prefix = 'segmentation'

data_key= prefix + '/customers_scaled.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)

# %%
tmp_list = []

for chunk in pd.read_csv(data_location, chunksize=100000):
    tmp_list.append(chunk)
    
df = pd.concat(tmp_list, axis=0).drop(['Unnamed: 0'], axis=1)
print(df.shape)
del tmp_list
# Out:
# (191652, 94)

# %%
df.head()
# Out:
#         LNR  AGER_TYP  D19_BANKEN_ANZ_12  D19_BANKEN_ANZ_24  D19_BANKEN_DATUM  \
# 0  0.050221      0.75           0.000000           0.000000          1.000000
# 1  0.050232      0.00           0.000000           0.166667          0.555556
# 2  0.750693      0.00           0.000000           0.000000          1.000000
# 3  0.750698      0.50           0.000000           0.000000          1.000000
# 4  0.750703      0.00           0.166667           0.333333          0.222222
#
#    D19_BANKEN_DIREKT  D19_BANKEN_GROSS  D19_BANKEN_LOKAL  \
# 0           0.000000          0.000000          0.000000
# 1           0.000000          0.833333          0.000000
# 2           0.000000          0.000000          0.000000
# 3           0.000000          0.000000          0.000000
# 4           0.714286          0.000000          0.428571
#
#    D19_BANKEN_OFFLINE_DATUM  D19_BANKEN_ONLINE_DATUM  ...  SEMIO_REL  \
# 0                       1.0                 1.000000  ...   0.166667
# 1                       1.0                 1.000000  ...   0.166667
# 2                       1.0                 1.000000  ...   0.000000
# 3                       1.0                 1.000000  ...   0.333333
# 4                       1.0                 0.666667  ...   0.500000
#
#    SEMIO_SOZ  SEMIO_TRADV  SEMIO_VERT  SHOPPER_TYP  VERS_TYP  ZABEOTYP  \
# 0   0.833333          0.0    0.833333         1.00  0.666667       0.4
# 1   0.333333          0.0    1.000000         1.00  0.666667       0.4
# 2   0.166667          0.0    0.333333         0.50  1.000000       0.4
# 3   0.833333          0.5    1.000000         0.25  0.666667       0.0
# 4   0.500000          0.5    0.666667         0.50  1.000000       0.0
#
#    ONLINE_PURCHASE  ANREDE_KZ  ALTERSKATEGORIE_GROB
# 0              0.0        0.0                 0.375
# 1              0.0        0.0                 0.375
# 2              0.0        1.0                 0.375
# 3              0.0        0.0                 0.375
# 4              0.0        0.0                 0.250
#
# [5 rows x 94 columns]

# %%
# prepare space to store model artifacts
prefix = 'pca'
output_path = 's3://{}/{}/'.format(bucket, prefix)
output_path
# Out:
# 's3://sagemaker-us-east-2-240038582877/pca/'

# %%
N_COMPONENTS = 10
pca = PCA(role=role,
          train_instance_count=1,
          train_instance_type='ml.c4.xlarge',
          output_path=output_path,
          num_components=N_COMPONENTS,
          sagemaker_session=session)

# %%
#must convert to RecordSet for built in sagemaker models

#convert df to np array (pass this to the deployed PCA model later)
train_data_np = df.values.astype('float32')

#convert to RecordSet format
formatted_train_data = pca.record_set(train_data_np)

# %%
pca.fit(formatted_train_data)
# Out:
# 2020-04-20 03:18:59 Starting - Starting the training job...
# 2020-04-20 03:19:00 Starting - Launching requested ML instances......
# 2020-04-20 03:20:28 Starting - Preparing the instances for training...
# 2020-04-20 03:20:57 Downloading - Downloading input data......
# 2020-04-20 03:21:59 Training - Training image download completed. Training in progress.
# 2020-04-20 03:21:59 Uploading - Uploading generated training model
# 2020-04-20 03:21:59 Completed - Training job completed
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/20/2020 03:21:50 INFO 139751624345408] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'_num_gpus': u'auto', u'_log_level': u'info', u'subtract_mean': u'true', u'force_dense': u'true', u'epochs': 1, u'algorithm_mode': u'regular', u'extra_components': u'-1', u'_kvstore': u'dist_sync', u'_num_kv_servers': u'auto'}
# [04/20/2020 03:21:50 INFO 139751624345408] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'94', u'mini_batch_size': u'500', u'num_components': u'10'}
# [04/20/2020 03:21:50 INFO 139751624345408] Final configuration: {u'num_components': u'10', u'_num_gpus': u'auto', u'_log_level': u'info', u'subtract_mean': u'true', u'force_dense': u'true', u'epochs': 1, u'algorithm_mode': u'regular', u'feature_dim': u'94', u'extra_components': u'-1', u'_kvstore': u'dist_sync', u'_num_kv_servers': u'auto', u'mini_batch_size': u'500'}
# [04/20/2020 03:21:50 WARNING 139751624345408] Loggers have already been setup.
# [04/20/2020 03:21:51 INFO 139751624345408] Launching parameter server for role scheduler
# [04/20/2020 03:21:51 INFO 139751624345408] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/8fc060d8-51ba-4b99-9265-6677d339754a', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-04-20-03-18-59-243', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-157-146.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d40ca84b-1566-47bc-8cef-4c62932119a4', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:240038582877:training-job/pca-2020-04-20-03-18-59-243', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/20/2020 03:21:51 INFO 139751624345408] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/8fc060d8-51ba-4b99-9265-6677d339754a', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.157.146', 'AWS_REGION': 'us-east-2', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-04-20-03-18-59-243', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-157-146.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d40ca84b-1566-47bc-8cef-4c62932119a4', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:240038582877:training-job/pca-2020-04-20-03-18-59-243', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/20/2020 03:21:51 INFO 139751624345408] Launching parameter server for role server
# [04/20/2020 03:21:51 INFO 139751624345408] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/8fc060d8-51ba-4b99-9265-6677d339754a', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-04-20-03-18-59-243', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-157-146.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d40ca84b-1566-47bc-8cef-4c62932119a4', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:240038582877:training-job/pca-2020-04-20-03-18-59-243', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/20/2020 03:21:51 INFO 139751624345408] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/8fc060d8-51ba-4b99-9265-6677d339754a', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.157.146', 'AWS_REGION': 'us-east-2', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-04-20-03-18-59-243', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-157-146.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d40ca84b-1566-47bc-8cef-4c62932119a4', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:240038582877:training-job/pca-2020-04-20-03-18-59-243', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/20/2020 03:21:51 INFO 139751624345408] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/8fc060d8-51ba-4b99-9265-6677d339754a', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '1', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.157.146', 'AWS_REGION': 'us-east-2', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-04-20-03-18-59-243', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-157-146.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d40ca84b-1566-47bc-8cef-4c62932119a4', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:240038582877:training-job/pca-2020-04-20-03-18-59-243', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 61 is a shell:scheduler.
# Process 70 is a shell:server.
# Process 1 is a worker.
# [04/20/2020 03:21:51 INFO 139751624345408] Using default worker.
# [04/20/2020 03:21:51 INFO 139751624345408] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [04/20/2020 03:21:51 INFO 139751624345408] Loaded iterator creator application/x-labeled-vector-protobuf for content type ('application/x-labeled-vector-protobuf', '1.0')
# [04/20/2020 03:21:51 INFO 139751624345408] Loaded iterator creator protobuf for content type ('protobuf', '1.0')
# [04/20/2020 03:21:51 INFO 139751624345408] Create Store: dist_sync
# [04/20/2020 03:21:52 INFO 139751624345408] nvidia-smi took: 0.0251760482788 secs to identify 0 gpus
# [04/20/2020 03:21:52 INFO 139751624345408] Number of GPUs being used: 0
# [04/20/2020 03:21:52 INFO 139751624345408] The default executor is <PCAExecutor on cpu(0)>.
# [04/20/2020 03:21:52 INFO 139751624345408] 94 feature(s) found in 'data'.
# [04/20/2020 03:21:52 INFO 139751624345408] <PCAExecutor on cpu(0)> is assigned to batch slice from 0 to 499.
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 751.655101776123, "sum": 751.655101776123, "min": 751.655101776123}}, "EndTime": 1587352912.674425, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1587352911.89866}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1587352912.674677, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1587352912.674622}
#
# [2020-04-20 03:21:52.675] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 775, "num_examples": 1, "num_bytes": 202000}
# [2020-04-20 03:21:53.074] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 391, "num_examples": 384, "num_bytes": 77427408}
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "update.time": {"count": 1, "max": 399.22404289245605, "sum": 399.22404289245605, "min": 399.22404289245605}}, "EndTime": 1587352913.074743, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1587352912.674543}
#
# [04/20/2020 03:21:53 INFO 139751624345408] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 384, "sum": 384.0, "min": 384}, "Number of Batches Since Last Reset": {"count": 1, "max": 384, "sum": 384.0, "min": 384}, "Number of Records Since Last Reset": {"count": 1, "max": 191652, "sum": 191652.0, "min": 191652}, "Total Batches Seen": {"count": 1, "max": 384, "sum": 384.0, "min": 384}, "Total Records Seen": {"count": 1, "max": 191652, "sum": 191652.0, "min": 191652}, "Max Records Seen Between Resets": {"count": 1, "max": 191652, "sum": 191652.0, "min": 191652}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1587352913.075124, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "PCA", "epoch": 0}, "StartTime": 1587352912.675477}
#
# [04/20/2020 03:21:53 INFO 139751624345408] #throughput_metric: host=algo-1, train throughput=479433.081707 records/second
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 19.494056701660156, "sum": 19.494056701660156, "min": 19.494056701660156}}, "EndTime": 1587352913.094847, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1587352913.074834}
#
# [04/20/2020 03:21:53 INFO 139751624345408] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2350.9469032287598, "sum": 2350.9469032287598, "min": 2350.9469032287598}, "setuptime": {"count": 1, "max": 1060.7478618621826, "sum": 1060.7478618621826, "min": 1060.7478618621826}}, "EndTime": 1587352913.102214, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1587352913.094901}
# Training seconds: 62
# Billable seconds: 62

# %%
#get from AWS console
training_job_name = 'pca-2020-04-20-03-18-59-243'
model_key = os.path.join(prefix, training_job_name, 'output/model.tar.gz')
print(model_key)

boto3.resource('s3').Bucket(bucket).download_file(model_key, 'model.tar.gz')

os.system('tar -zxvf model.tar.gz')
os.system('unzip model_algo-1')
# Out:
# pca/pca-2020-04-20-03-18-59-243/output/model.tar.gz
# 2304

# %%
# !pip install mxnet
import mxnet as mx

pca_model_params = mx.ndarray.load('model_algo-1')

print(pca_model_params)
# Out:
# Collecting mxnet
#   Downloading https://files.pythonhosted.org/packages/81/f5/d79b5b40735086ff1100c680703e0f3efc830fa455e268e9e96f3c857e93/mxnet-1.6.0-py2.py3-none-any.whl (68.7MB)
#     100% |████████████████████████████████| 68.7MB 614kB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.20.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from mxnet) (2.20.0)
# Collecting numpy<2.0.0,>1.16.0 (from mxnet)
#   Downloading https://files.pythonhosted.org/packages/3d/fc/4763e5f17ac6e7e7d55f377cde859ca1c5d5ac624441ab45315bc578aa9e/numpy-1.18.3-cp36-cp36m-manylinux1_x86_64.whl (20.2MB)
#     100% |████████████████████████████████| 20.2MB 2.0MB/s eta 0:00:01
# Collecting graphviz<0.9.0,>=0.8.1 (from mxnet)
#   Downloading https://files.pythonhosted.org/packages/53/39/4ab213673844e0c004bed8a0781a0721a3f6bb23eb8854ee75c236428892/graphviz-0.8.4-py2.py3-none-any.whl
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (
s=pd.DataFrame(pca_model_params['s'].asnumpy())
v=pd.DataFrame(pca_model_params['v'].asnumpy())

n_principal_components = 5

start_idx = N_COMPONENTS - n_principal_components

print(s.iloc[start_idx:])
# Out:
#             0
# 5  193.034317
# 6  221.538742
# 7  319.528595
# 8  337.852325
# 9  675.316345

# %%
#what is the smallest number or principal comonents that captures at least 80% of the
#total variance in the dataset?

def explained_variance(s, n_top_components):
#     exp_variance = np.square(s.iloc[start_idx:])
    exp_variance = np.square(s.iloc[start_idx:]).sum() / np.square(s).sum()
    return exp_variance

# %%
n_top_components = 10
exp_variance = explained_variance(s, n_top_components)
print(exp_variance)
# Out:
# 0    0.848037
# dtype: float32

# %% [markdown]
# ### Component Features

# %%
df.columns.values;

# %%
corr_matrix = df.corr().abs()
c2 = corr_matrix.unstack().sort_values(ascending=False).to_frame()
# set(c2[np.logical_and(c2[0] > 0.8, c2[0] < 1)].index.values)

# %%
corr_matrix.style.background_gradient(cmap='coolwarm');

# %%
import seaborn as sns

def display_component(v, features_list, component_num, n_weights=10):
        row_idx = N_COMPONENTS-component_num
        v_l_row = v.iloc[:, row_idx]
        v_1 = np.squeeze(v_l_row.values)
        
        compos = pd.DataFrame(list(zip(v_1, features_list)), columns=['weights', 'features'])
        
        # get absolute value
        #weights can be neg/pos and we'll sort by magnitude
        
        compos['abs_weights'] = compos['weights'].apply(lambda x: abs(x))
        sorted_compos = compos.sort_values('abs_weights', ascending=False).head(n_weights)
        print(sorted_compos)
        
        ax=plt.subplots(figsize=(10,6))
        ax=sns.barplot(data=sorted_compos, x="weights", y="features", palette="Blues_d")
        ax.set_title("PCA Component Makeup Component #{}".format(component_num))
        plt.show()

# %%
display_component(v, df.columns.values, component_num=3, n_weights=10)
# Out:
#      weights    features  abs_weights
# 92  0.573094   ANREDE_KZ     0.573094
# 77  0.291069  SEMIO_KAEM     0.291069
# 79 -0.278806  SEMIO_KULT     0.278806
# 75  0.269289   SEMIO_ERL     0.269289
# 76 -0.260711   SEMIO_FAM     0.260711
# 87 -0.241872  SEMIO_VERT     0.241872
# 78  0.237503  SEMIO_KRIT     0.237503
# 84 -0.205353   SEMIO_REL     0.205353
# 74  0.199207   SEMIO_DOM     0.199207
# 81 -0.174904   SEMIO_MAT     0.174904

# %% [markdown]
# ### Deploying the PCA Model

# %%
# %%time

pca_predictor = pca.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# -------------!CPU times: user 232 ms, sys: 26.2 ms, total: 258 ms
# Wall time: 6min 31s

# %%
#try chunking data to PCA endpoint
train_pca = []

for chunk in np.array_split(train_data_np, 120):
    train_pca.append(pca_predictor.predict(chunk))

# %%
flattened_train_pca = [list for sublist in train_pca for list in sublist]

# %%
len(flattened_train_pca)
# Out:
# 191652

# %%
flattened_train_pca[:1]
# Out:
# [label {
#    key: "projection"
#    value {
#      float32_tensor {
#        values: -0.16242478787899017
#        values: 0.5052165985107422
#        values: 0.06504058092832565
#        values: 0.025744855403900146
#        values: -0.13618135452270508
#        values: 0.4858267307281494
#        values: -0.4106006622314453
#        values: -0.8425292372703552
#        values: -1.2443734407424927
#        values: 0.677014946937561
#      }
#    }
#  }]

# %%
def create_transformed_df(flattened_train_pca, scaled_df, n_top_components):
    start_idx = N_COMPONENTS - n_top_components
    new_values = [x.label['projection'].float32_tensor.values for x in flattened_train_pca]
    df = pd.DataFrame(index=scaled_df.index.values, data=new_values)
    
    top_components = df.iloc[:,start_idx:]
    return top_components.iloc[:,::-1]

# %%
top_n = 10

df_transformed = create_transformed_df(flattened_train_pca, df, n_top_components=top_n)
df_transformed.columns = ['c1', 'c2', 'c3', 'c4', 'c5','c6', 'c7', 'c8', 'c9', 'c10',]
df_transformed.head(10)
# Out:
#          c1        c2        c3        c4        c5        c6        c7  \
# 0  0.677015 -1.244373 -0.842529 -0.410601  0.485827 -0.136181  0.025745
# 1 -0.099502 -0.627401 -0.703490  0.548027 -0.129998 -0.392206  0.647169
# 2 -0.250697 -1.095524  1.005910 -0.393866  0.864190  0.079857  0.270307
# 3  0.246221 -0.627549 -0.723070  0.298049 -0.281638 -0.404650  0.267531
# 4  1.273728  1.928221 -0.325409  0.598047 -0.462535  0.107080  0.155315
# 5  0.944657 -0.769333 -0.460911 -0.336605  0.498368  0.021957  0.223411
# 6  1.586115  0.129128 -0.373730 -0.410575  0.338653 -0.361434 -0.776559
# 7  0.574226 -0.794567 -0.749681  0.618750  0.544540 -0.074489 -0.194860
# 8  0.144483 -0.845178  1.589080  0.261412 -0.437072 -0.381223 -0.237910
# 9  1.984327  1.049471 -0.395020 -0.109483  0.335382  0.441227  0.504532
#
#          c8        c9       c10
# 0  0.065041  0.505217 -0.162425
# 1 -0.318942  0.289289  0.332218
# 2  0.746444  0.490394  0.109186
# 3 -0.240617  0.233776  0.057038
# 4 -0.009972  0.348369 -0.327568
# 5 -0.020818 -0.309288  0.139389
# 6 -0.363544  0.214883  0.084859
# 7 -0.596445  0.436758 -0.176771
# 8  0.526266  0.418868 -0.161354
# 9 -0.692026 -0.161713 -0.622192

# %%
session.delete_endpoint(pca_predictor.endpoint)

# %%
# KMeans

from sagemaker import KMeans

prefix = 'segmentation'
output_path = 's3://{}/{}/'.format(bucket, prefix)
print(output_path)
# Out:
# s3://sagemaker-us-east-2-240038582877/segmentation/

# %%
kmeans = KMeans(
    role=role,
    train_instance_count=1,
    train_instance_type='ml.c4.xlarge',
    output_path=output_path,
    sagemaker_session=session,
    k=8
)

# %%
train_data_np = df_transformed.values.astype('float32')
formatted_train_data = kmeans.record_set(train_data_np)

# %%
# %%time
kmeans.fit(formatted_train_data)
# Out:
# 2020-04-16 13:21:50 Starting - Starting the training job...
# 2020-04-16 13:21:52 Starting - Launching requested ML instances...
# 2020-04-16 13:22:47 Starting - Preparing the instances for training......
# 2020-04-16 13:23:39 Downloading - Downloading input data......
# 2020-04-16 13:24:47 Training - Training image download completed. Training in progress.
# 2020-04-16 13:24:47 Uploading - Uploading generated training model
# 2020-04-16 13:24:47 Completed - Training job completed
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/16/2020 13:24:39 INFO 139962932578112] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'_enable_profiler': u'false', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [04/16/2020 13:24:39 INFO 139962932578112] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'10', u'k': u'8', u'force_dense': u'True'}
# [04/16/2020 13:24:39 INFO 139962932578112] Final configuration: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'feature_dim': u'10', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'8', u'_num_slices': u'1'}
# [04/16/2020 13:24:39 WARNING 139962932578112] Loggers have already been setup.
# Process 1 is a worker.
# [04/16/2020 13:24:39 INFO 139962932578112] Using default worker.
# [04/16/2020 13:24:39 INFO 139962932578112] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [04/16/2020 13:24:39 INFO 139962932578112] Create Store: local
# [04/16/2020 13:24:39 INFO 139962932578112] nvidia-smi took: 0.025267124176 secs to identify 0 gpus
# [04/16/2020 13:24:39 INFO 139962932578112] Number of GPUs being used: 0
# [04/16/2020 13:24:39 INFO 139962932578112] Setting up with params: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'feature_dim': u'10', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'8', u'_num_slices': u'1'}
# [04/16/2020 13:24:39 INFO 139962932578112] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [04/16/2020 13:24:39 INFO 139962932578112] Number of GPUs being used: 0
# [04/16/2020 13:24:39 INFO 139962932578112] number of center slices 1
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Max Records Seen Between Resets": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1587043479.125462, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1587043479.125405}
#
# [2020-04-16 13:24:39.128] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 52, "num_examples": 1, "num_bytes": 320000}
# [04/16/2020 13:24:39 INFO 139962932578112] Iter 10: Short term msd 0.832441. Long term msd 0.871292
# [04/16/2020 13:24:39 INFO 139962932578112] Iter 20: Short term msd 0.790942. Long term msd 0.812426
# [04/16/2020 13:24:39 INFO 139962932578112] Iter 30: Short term msd 0.800415. Long term msd 0.801448
# [2020-04-16 13:24:39.626] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 497, "num_examples": 39, "num_bytes": 12265728}
# [04/16/2020 13:24:39 INFO 139962932578112] processed a total of 191652 examples
# [04/16/2020 13:24:39 INFO 139962932578112] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 39, "sum": 39.0, "min": 39}, "Number of Batches Since Last Reset": {"count": 1, "max": 39, "sum": 39.0, "min": 39}, "Number of Records Since Last Reset": {"count": 1, "max": 191652, "sum": 191652.0, "min": 191652}, "Total Batches Seen": {"count": 1, "max": 40, "sum": 40.0, "min": 40}, "Total Records Seen": {"count": 1, "max": 196652, "sum": 196652.0, "min": 196652}, "Max Records Seen Between Resets": {"count": 1, "max": 191652, "sum": 191652.0, "min": 191652}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1587043479.627458, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1587043479.128679}
#
# [04/16/2020 13:24:39 INFO 139962932578112] #throughput_metric: host=algo-1, train throughput=384138.345897 records/second
# [04/16/2020 13:24:39 WARNING 139962932578112] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/16/2020 13:24:39 INFO 139962932578112] shrinking 80 centers into 8
# [04/16/2020 13:24:39 INFO 139962932578112] local kmeans attempt #0. Current mean square distance 0.680714
# [04/16/2020 13:24:39 INFO 139962932578112] local kmeans attempt #1. Current mean square distance 0.703667
# [04/16/2020 13:24:39 INFO 139962932578112] local kmeans attempt #2. Current mean square distance 0.681153
# [04/16/2020 13:24:39 INFO 139962932578112] local kmeans attempt #3. Current mean square distance 0.676564
# [04/16/2020 13:24:39 INFO 139962932578112] local kmeans attempt #4. Current mean square distance 0.717256
# [04/16/2020 13:24:39 INFO 139962932578112] local kmeans attempt #5. Current mean square distance 0.681574
# [04/16/2020 13:24:39 INFO 139962932578112] local kmeans attempt #6. Current mean square distance 0.689613
# [04/16/2020 13:24:39 INFO 139962932578112] local kmeans attempt #7. Current mean square distance 0.737022
# [04/16/2020 13:24:39 INFO 139962932578112] local kmeans attempt #8. Current mean square distance 0.707160
# [04/16/2020 13:24:39 INFO 139962932578112] local kmeans attempt #9. Current mean square distance 0.675216
# [04/16/2020 13:24:39 INFO 139962932578112] finished shrinking process. Mean Square Distance = 1
# [04/16/2020 13:24:39 INFO 139962932578112] #quality_metric: host=algo-1, train msd <loss>=0.675216078758
# [04/16/2020 13:24:39 INFO 139962932578112] predict compute msd took: 34.0589%, (0.169552 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] gradient: cluster size  took: 21.5380%, (0.107220 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] compute all data-center distances: inner product took: 17.4194%, (0.086717 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] gradient: cluster center took: 6.0951%, (0.030343 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] compute all data-center distances: point norm took: 5.4315%, (0.027039 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] batch data loading with context took: 3.5065%, (0.017456 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] gradient: one_hot took: 3.1661%, (0.015761 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] update state and report convergance took: 3.1023%, (0.015444 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] collect from kv store took: 2.5135%, (0.012513 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] splitting centers key-value pair took: 1.6987%, (0.008456 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] compute all data-center distances: center norm took: 1.2949%, (0.006446 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] predict minus dist took: 0.1340%, (0.000667 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] update set-up time took: 0.0410%, (0.000204 secs)
# [04/16/2020 13:24:39 INFO 139962932578112] TOTAL took: 0.497818946838
# [04/16/2020 13:24:39 INFO 139962932578112] Number of GPUs being used: 0
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 235.07118225097656, "sum": 235.07118225097656, "min": 235.07118225097656}, "initialize.time": {"count": 1, "max": 41.32485389709473, "sum": 41.32485389709473, "min": 41.32485389709473}, "model.serialize.time": {"count": 1, "max": 0.1380443572998047, "sum": 0.1380443572998047, "min": 0.1380443572998047}, "update.time": {"count": 1, "max": 498.58808517456055, "sum": 498.58808517456055, "min": 498.58808517456055}, "epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "state.serialize.time": {"count": 1, "max": 2.0508766174316406, "sum": 2.0508766174316406, "min": 2.0508766174316406}, "_shrink.time": {"count": 1, "max": 233.3080768585205, "sum": 233.3080768585205, "min": 233.3080768585205}}, "EndTime": 1587043479.865184, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1587043479.075554}
#
# [04/16/2020 13:24:39 INFO 139962932578112] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 856.1460971832275, "sum": 856.1460971832275, "min": 856.1460971832275}, "setuptime": {"count": 1, "max": 16.561031341552734, "sum": 16.561031341552734, "min": 16.561031341552734}}, "EndTime": 1587043479.865504, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1587043479.865277}
# Training seconds: 68
# Billable seconds: 68
# CPU times: user 388 ms, sys: 10.3 ms, total: 398 ms
# Wall time: 3min 11s

# %%
# %%time
kmeans_predictor = kmeans.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# -----------------!CPU times: user 271 ms, sys: 41.3 ms, total: 312 ms
# Wall time: 8min 32s

# %%
# %%time
# cluster_info=kmeans_predictor.predict(train_data_np)


#try chunking data to PCA endpoint
cluster_info = []

for chunk in np.array_split(train_data_np, 120):
    cluster_info.append(kmeans_predictor.predict(chunk))
# Out:
# CPU times: user 12.8 s, sys: 163 ms, total: 12.9 s
# Wall time: 20.7 s

# %%
#explore clusters
data_idx = 0

print(df_transformed.index[data_idx])
cluster_info[data_idx]
# Out:
# 0
# [label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.1701784133911133
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.0941143035888672
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.4823265075683594
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.8010857701301575
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.359081506729126
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.7713428139686584
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.9986884593963623
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.9813064336776733
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.1558129787445068
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 5.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.2784109115600586
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 0.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.70639967918396
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.2771222591400146
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.7237728238105774
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.3120557069778442
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.2528891563415527
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.0054335594177246
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.1242716312408447
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 5.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.4955739974975586
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.937021017074585
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1
0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.256504774093628
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.084671974182129
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.2607710361480713
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29589521884918213
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29589521884918213
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.370858907699585
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3161250650882721
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.2972377836704254
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.9769883155822754
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 7.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 2.179443120956421
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.36656299233436584
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3182485103607178
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.3185068368911743
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.3598518371582031
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31477293372154236
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.1515620946884155
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31477293372154236
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 5.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.905359148979187
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.32839229702949524
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.4228991270065308
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 2.1539993286132812
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.2958734631538391
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29612797498703003
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31479185819625854
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29612797498703003
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.2972177267074585
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3333405554294586
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29612797498703003
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29612797498703003
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.2958718538284302
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3147933781147003
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31477293372154236
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3161250650882721
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.2958928048610687
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.450385570526123
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 0.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.9561024904251099
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3161250650882721
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29723697900772095
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 0.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.934813380241394
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.1669198274612427
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 0.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.3033989667892456
#      }
#    }
#  }, label {
#    key: "closest_cluster"
# ...
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31909844279289246
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.1873855590820312
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.348788857460022
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3156110346317291
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29526039958000183
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29633966088294983
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29633966088294983
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.37077686190605164
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29501160979270935
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29633966088294983
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3156110346317291
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.2557122707366943
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31697240471839905
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.060485601425171
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29526039958000183
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.4954309463500977
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 7.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.4644908905029297
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 5.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.1861289739608765
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.681043267250061
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.8870362639427185
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.707053303718567
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 7.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.273306965827942
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3280923068523407
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.2963597774505615
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29528141021728516
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.3939239978790283
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.328093022108078
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31907975673675537
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3155921399593353
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29694807529449463
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29721933603286743
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29721933603286743
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.298309862613678
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29721933603286743
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.746077537536621
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 7.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.440596342086792
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.5129952430725098
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.9062538146972656
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31731969118118286
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31731969118118286
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29694727063179016
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 7.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.6140247583389282
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29721853137016296
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31520208716392517
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.2983090877532959
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.36837318539619446
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31385281682014465
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.0165693759918213
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.4381320476531982
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31731969118118286
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29721853137016296
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31385356187820435
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29721853137016296
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.2983090877532959
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3138550817966461
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.31731894612312317
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.298309862613678
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3288102149963379
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29694968461990356
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.3090285062789917
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.5369282960891724
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.3554819822311401
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.3138550817966461
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29694968461990356
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29694968461990356
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.47299325466156
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 2.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.9284939169883728
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 1.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.29732999205589294
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 3.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.3855137825012207
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 6.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.8434129953384399
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 4.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 0.9661098718643188
#      }
#    }
#  }, label {
#    key: "closest_cluster"
#    value {
#      float32_tensor {
#        values: 5.0
#      }
#    }
#  }
#  label {
#    key: "distance_to_cluster"
#    value {
#      float32_tensor {
#        values: 1.3382039070129395
#      }
#    }
#  }, ...]

# %%
flattened_cluster_info = [list for sublist in cluster_info for list in sublist]

# %%
len(flattened_cluster_info)
# Out:
# 191652

# %%
cluster_labels = [c.label['closest_cluster'].float32_tensor.values[0] for c in flattened_cluster_info]

# %%
cluster_df = pd.DataFrame(cluster_labels)[0].value_counts()

print(cluster_df)
# Out:
# 1.0    47194
# 2.0    25978
# 4.0    24618
# 3.0    23235
# 0.0    21249
# 6.0    21032
# 7.0    19479
# 5.0     8867
# Name: 0, dtype: int64

# %%
session.delete_endpoint(kmeans_predictor.endpoint)
